# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('TopSellingAlbums.csv')
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
x=df['Length']
x
# Out:
# 0    0:42:19
# 1    0:42:11
# 2    0:42:49
# 3    0:57:44
# 4    0:46:33
# 5    0:43:08
# 6    1:15:54
# 7    0:40:01
# Name: Length, dtype: object

# %%
x=df[['Length']]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %%
y=df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %%
df.loc[0,'Artist']
# Out:
# 'Michael Jackson'

# %%
df.loc[7,'Artist']
# Out:
# 'Fleetwood Mac'

# %%
df.iloc[0,0]
# Out:
# 'Michael Jackson'

# %%
df.iloc[7,0]
# Out:
# 'Fleetwood Mac'

# %%
df.loc[0:5,'Artist':'Released']
# Out:
#             Artist                            Album  Released
# 0  Michael Jackson                         Thriller      1982
# 1            AC/DC                    Back in Black      1980
# 2       Pink Floyd        The Dark Side of the Moon      1973
# 3  Whitney Houston                    The Bodyguard      1992
# 4        Meat Loaf                  Bat Out of Hell      1977
# 5           Eagles  Their Greatest Hits (1971-1975)      1976

# %%
df['Artist'].unique()
# Out:
# array(['Michael Jackson', 'AC/DC', 'Pink Floyd', 'Whitney Houston',
#        'Meat Loaf', 'Eagles', 'Bee Gees', 'Fleetwood Mac'], dtype=object)

# %%
df['Released']>=1980
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Released, dtype: bool

# %%
df1=df[df['Released']>=1980]
df1
# Out:
#             Artist          Album  Released   Length           Genre  \
# 0  Michael Jackson       Thriller      1982  0:42:19  pop, rock, R&B
# 1            AC/DC  Back in Black      1980  0:42:11       hard rock
# 3  Whitney Houston  The Bodyguard      1992  0:57:44  R&B, soul, pop
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 0                              46.0                        65  30-Nov-82
# 1                              26.1                        50  25-Jul-80
# 3                              27.4                        44  17-Nov-92
#
#   Soundtrack  Rating
# 0        NaN    10.0
# 1        NaN     9.5
# 3          Y     8.5

# %%
df1.to_csv('New_songs.csv')

# %%
df=pd.read_csv('artwork_data.csv',low_memory=False)
df
# Out:
#            id accession_number  \
# 0        1035           A00001
# 1        1036           A00002
# 2        1037           A00003
# 3        1038           A00004
# 4        1039           A00005
# 5        1040           A00006
# 6        1041           A00007
# 7        1042           A00008
# 8        1043           A00009
# 9        1044           A00010
# 10       1045           A00011
# 11       1046           A00012
# 12       1047           A00013
# 13       1048           A00014
# 14       1049           A00015
# 15       1050           A00016
# 16       1051           A00017
# 17       1052           A00018
# 18       1053           A00019
# 19       1054           A00020
# 20       1055           A00021
# 21       1056           A00022
# 22       1057           A00023
# 23       1058           A00024
# 24       1059           A00025
# 25       1060           A00026
# 26       1061           A00027
# 27       1062           A00028
# 28       1063           A00029
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=7)
df
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=5,index_col='id')
df
# Out:
#      accession_number          artist artistRole  artistId  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# 1039  The Circle of the Lustful: Francesca da Rimini...
#
#                     dateText  \
# id
# 1035          date not known
# 1036          date not known
# 1037                 ?c.1785
# 1038          date not known
# 1039  1826–7, reprinted 1892
#
#                                                  medium  \
# id
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=3,index_col='artistId')
df
# Out:
#             id accession_number         artist artistRole  \
# artistId
# 38        1035           A00001  Blake, Robert     artist
# 38        1036           A00002  Blake, Robert     artist
# 38        1037           A00003  Blake, Robert     artist
#
#                                                       title        dateText  \
# artistId
# 38        A Figure Bowing before a Seated Old Man with h...  date not known
# 38        Two Drawings of Frightened Figures, Probably f...  date not known
# 38        The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                                      medium  \
# artistId
# 38        Watercolour, ink, chalk and graphite on paper....
# 38                                        Graphite on paper
# 38              Graphite on paper. Verso: graphite on paper
#
#                                    creditLine    year  acquisitionYear  \
# artistId
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=3,index_col='artistId')
df
# Out:
#             id accession_number         artist artistRole  \
# artistId
# 38        1035           A00001  Blake, Robert     artist
# 38        1036           A00002  Blake, Robert     artist
# 38        1037           A00003  Blake, Robert     artist
#
#                                                       title        dateText  \
# artistId
# 38        A Figure Bowing before a Seated Old Man with h...  date not known
# 38        Two Drawings of Frightened Figures, Probably f...  date not known
# 38        The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                                      medium  \
# artistId
# 38        Watercolour, ink, chalk and graphite on paper....
# 38                                        Graphite on paper
# 38              Graphite on paper. Verso: graphite on paper
#
#                                    creditLine    year  acquisitionYear  \
# artistId
# ...

# %%
df2=pd.read_csv('artwork_data.csv',nrows=20,index_col='id',usecols=['id','artistId','artist'])
df2
# Out:
#               artist  artistId
# id
# 1035   Blake, Robert        38
# 1036   Blake, Robert        38
# 1037   Blake, Robert        38
# 1038   Blake, Robert        38
# 1039  Blake, William        39
# 1040  Blake, William        39
# 1041  Blake, William        39
# 1042  Blake, William        39
# 1043  Blake, William        39
# 1044  Blake, William        39
# 1045  Blake, William        39
# 1046  Blake, William        39
# 1047  Blake, William        39
# 1048  Blake, William        39
# 1049  Blake, William        39
# 1050  Blake, William        39
# 1051  Blake, William        39
# 1052  Blake, William        39
# 1053  Blake, William        39
# 1054  Blake, William        39

# %%
mul_cols=['id','artist','title','medium','year','units']
df=pd.read_csv('artwork_data.csv',nrows=5,index_col='id',usecols=mul_cols)
df
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                                  medium    year units
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN    mm
# 1036                                  Graphite on paper     NaN    mm
# 1037        Graphite on paper. Verso: graphite on paper  1785.0    mm
# 1038                                  Graphite on paper     NaN    mm
# 1039                            Line engraving on paper  1826.0    mm

# %%
df.to_pickle('output1.pickle')

# %%
df3=pd.read_pickle('output1.pickle')

# %%
df3
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                                  medium    year units
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN    mm
# 1036                                  Graphite on paper     NaN    mm
# 1037        Graphite on paper. Verso: graphite on paper  1785.0    mm
# 1038                                  Graphite on paper     NaN    mm
# 1039                            Line engraving on paper  1826.0    mm

# %%
artists=df['artist']

len(pd.unique('artists'))
# Out:
# 1

# %%
artists
# Out:
# id
# 1035     Blake, Robert
# 1036     Blake, Robert
# 1037     Blake, Robert
# 1038     Blake, Robert
# 1039    Blake, William
# Name: artist, dtype: object

# %%
df=pd.read_csv('artwork_data.csv',low_memory=False)
df
# Out:
#            id accession_number  \
# 0        1035           A00001
# 1        1036           A00002
# 2        1037           A00003
# 3        1038           A00004
# 4        1039           A00005
# 5        1040           A00006
# 6        1041           A00007
# 7        1042           A00008
# 8        1043           A00009
# 9        1044           A00010
# 10       1045           A00011
# 11       1046           A00012
# 12       1047           A00013
# 13       1048           A00014
# 14       1049           A00015
# 15       1050           A00016
# 16       1051           A00017
# 17       1052           A00018
# 18       1053           A00019
# 19       1054           A00020
# 20       1055           A00021
# 21       1056           A00022
# 22       1057           A00023
# 23       1058           A00024
# 24       1059           A00025
# 25       1060           A00026
# 26       1061           A00027
# 27       1062           A00028
# 28       1063           A00029
# ...

# %%
artists=df['artist']

len(pd.unique(artists))
# Out:
# 3336

# %%
gg=pd.unique(artists)
gg
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       dtype=object)

# %%
a = df['artist'] == 'Creed, Martin'
a.value_counts()
# Out:
# False    69188
# True        13
# Name: artist, dtype: int64

# %%
artist_counts = df['artist'].value_counts()
print(artist_counts)
# Out:
# Turner, Joseph Mallord William        39389
# Jones, George                          1046
# Moore, Henry, OM, CH                    623
# Daniell, William                        612
# Beuys, Joseph                           578
# British (?) School                      388
# Paolozzi, Sir Eduardo                   385
# Flaxman, John                           287
# Phillips, Esq Tom                       274
# Warhol, Andy                            272
# Constable, John                         249
# Cozens, Alexander                       237
# Stothard, Thomas                        215
# Ferrari, León                           199
# Piper, John                             183
# Blake, William                          180
# Kitaj, R.B.                             179
# Dance-Holland, Sir Nathaniel            169
# Hamilton Finlay, Ian                    164
# Flanagan, Barry                         162
# Gainsborough, Thomas                    158
# ...

# %%
artist_counts['Jones, George']
# Out:
# 1046

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x=[12,16,18,24]
y=[20,17,11,7]
plt.plot(x,y)
plt.show()

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)
plt.show()

# %%
plt.title('Sales-Performance')
plt.plot(x,y)
plt.show()

# %%
x=[12,16,18,24]
y=[20,17,11,7]
plt.plot(x,y)

z=[8,12,16,21]
plt.plot(x,z)

plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.title('Sales-Performance')
plt.legend(['This is height','This is weight'])
plt.show()

# %%
file=pd.read_csv('C:/Users/vivek/Downloads/sample_data.csv')
file
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(file)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(file.column_a,file.column_b,file.column_c)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sample Sale Graph')
plt.legend(['sales','revenue'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(file.column_a,file.column_b,file.column_c,'+')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sample Sale Graph')
plt.legend(['sales','revenue'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
file2=pd.read_csv('C:/Users/vivek/Downloads/countries.csv')
file2.head()
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
file2.tail()
# Out:
#        country  year  population
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
df=pd.read_csv('C:/Users/vivek/Downloads/countries.csv',nrows=9,index_col='year')
df
# Out:
#           country  population
# year
# 1952  Afghanistan     8425333
# 1957  Afghanistan     9240934
# 1962  Afghanistan    10267083
# 1967  Afghanistan    11537966
# 1972  Afghanistan    13079460
# 1977  Afghanistan    14880372
# 1982  Afghanistan    12881816
# 1987  Afghanistan    13867957
# 1992  Afghanistan    16317921

# %%
df=pd.read_csv('C:/Users/vivek/Downloads/countries.csv',nrows=9,index_col='year',usecols=['year','population'])
df
# Out:
#       population
# year
# 1952     8425333
# 1957     9240934
# 1962    10267083
# 1967    11537966
# 1972    13079460
# 1977    14880372
# 1982    12881816
# 1987    13867957
# 1992    16317921

# %%
temp=file2['country']
pd.unique(temp)
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
Af=file2[file2['country']=='Afghanistan']
Al=file2[file2['country']=='Albania']

plt.plot(Af['year'],Af['population'])
plt.plot(Al['year'],Al['population'])

plt.show()

# %%
Af=file2[file2['country']=='Afghanistan']
Al=file2[file2['country']=='Albania']

plt.plot(Af['population'],Af['year'],Al['population'],)


plt.show()

# %%
Af=file2[file2['country']=='Afghanistan']
Al=file2[file2['country']=='Albania']

plt.plot(Af.year,Af.population)
plt.plot(Al.year,Al.population)


plt.show()
